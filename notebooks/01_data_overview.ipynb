# %%
import pandas as pd
from pathlib import Path

# Şu anki çalışma dizini: .../ai-job-skill-gap-analyzer/notebooks
# Bir seviye yukarı çıkmamız yeterli
BASE_DIR = Path.cwd().parent

DATA_DIR = BASE_DIR / "data"
RAW_DATA_DIR = DATA_DIR / "raw"

print("BASE_DIR:", BASE_DIR)
print("RAW_DATA_DIR:", RAW_DATA_DIR)
print("RAW_DATA_DIR exists?:", RAW_DATA_DIR.exists())
# Out:
# BASE_DIR: c:\Projects\ai-job-skill-gap-analyzer
# RAW_DATA_DIR: c:\Projects\ai-job-skill-gap-analyzer\data\raw
# RAW_DATA_DIR exists?: True

# %%
csv_path = RAW_DATA_DIR / "us_tech_jobs.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#                                        advertiserurl  \
# 0  https://www.dice.com/jobs/detail/AUTOMATION-TE...
# 1  https://www.dice.com/jobs/detail/Information-S...
# 2  https://www.dice.com/jobs/detail/Business-Solu...
# 3  https://www.dice.com/jobs/detail/Java-Develope...
# 4  https://www.dice.com/jobs/detail/DevOps-Engine...
#
#                              company  \
# 0  Digital Intelligence Systems, LLC
# 1  University of Chicago/IT Services
# 2               Galaxy Systems, Inc.
# 3                      TransTech LLC
# 4                   Matrix Resources
#
#                             employmenttype_jobstatus  \
# 0  C2H Corp-To-Corp, C2H Independent, C2H W2, 3 M...
# 1                                          Full Time
# 2                                          Full Time
# 3                                          Full Time
# 4                                          Full Time
#
#                                       jobdescription               jobid  \
# ...

# %%
df.shape
# Out:
# (22000, 12)

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# site_name                   0.841364
# shift                       0.016227
# employmenttype_jobstatus    0.010455
# company                     0.002273
# skills                      0.001955
# joblocation_address         0.000136
# jobdescription              0.000000
# advertiserurl               0.000000
# postdate                    0.000000
# jobtitle                    0.000000
# jobid                       0.000000
# uniq_id                     0.000000
# dtype: float64

# %%
df[["jobtitle", "jobdescription", "skills"]].head(20)
# Out:
#                                              jobtitle  \
# 0                            AUTOMATION TEST ENGINEER
# 1                       Information Security Engineer
# 2                        Business Solutions Architect
# 3   Java Developer (mid level)- FT- GREAT culture,...
# 4                                     DevOps Engineer
# 5                                  SAP FICO Architect
# 6                                    Network Engineer
# 7   Sr. Web Application Developer (Cloud Team) - C...
# 8                                 Front End Developer
# 9                        Application Support Engineer
# 10                         OpenStack Engineer - 12185
# 11      9001 Data Security Administrator - Unix & IAM
# 12                          Software Engineer Manager
# 13                        Sales Engineer - Los Angles
# 14                                    Project Manager
# 15                       Windows System Administrator
# ...
