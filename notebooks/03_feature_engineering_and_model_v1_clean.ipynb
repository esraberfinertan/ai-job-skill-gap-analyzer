# %%
import os
os.getcwd()
# Out:
# 'c:\\Projects\\ai-job-skill-gap-analyzer\\notebooks'

# %%
import sys
from pathlib import Path

BASE_DIR = Path.cwd().parent
sys.path.append(str(BASE_DIR))

# %%
from src.features import (
    parse_skills_column,
    rebuild_skills_list,
    build_skill_profiles
)

# %% [markdown]
# # Feature Engineering & Baseline Model (v1)
#
# Bu notebook'ta:
# 1. Temizlenmiş iş ilanı verisini yüklüyoruz
# 2. TF-IDF tabanlı feature engineering yapıyoruz
# 3. K-means ile job role clustering yapıyoruz
# 4. Cluster bazlı skill profilleri çıkarıyoruz

# %%
import pandas as pd
from pathlib import Path
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans
from collections import Counter
import ast
import re

BASE_DIR = Path.cwd().parent
DATA_DIR = BASE_DIR / "data"
PROCESSED_DATA_DIR = DATA_DIR / "processed"

csv_path = PROCESSED_DATA_DIR / "jobs_clean.csv"
df = pd.read_csv(csv_path)

df.head()
# Out:
#                              company  \
# 0  Digital Intelligence Systems, LLC
# 1  University of Chicago/IT Services
# 2               Galaxy Systems, Inc.
# 3                      TransTech LLC
# 4                   Matrix Resources
#
#                             employmenttype_jobstatus  \
# 0  C2H Corp-To-Corp, C2H Independent, C2H W2, 3 M...
# 1                                          Full Time
# 2                                          Full Time
# 3                                          Full Time
# 4                                          Full Time
#
#                                       jobdescription joblocation_address  \
# 0  Looking for Selenium engineers...must have sol...         Atlanta, GA
# 1  The University of Chicago has a rapidly growin...         Chicago, IL
# 2  GalaxE.SolutionsEvery day, our solutions affec...      Schaumburg, IL
# 3  Java DeveloperFull-time/direct-hireBolingbrook...     Bolingbrook, IL
# 4  Midtown based high tech firm has an immediate ...         Atlanta, GA
#
#                                             jobtitle        postdate  \
# 0                           AUTOMATION TEST ENGINEER      1 hour ago
# 1                      Information Security Engineer      1 week ago
# 2                       Business Solutions Architect     2 weeks ago
# 3  Java Developer (mid level)- FT- GREAT culture,...     2 weeks ago
# 4                                    DevOps Engineer  48 minutes ago
#
#                                               skills  \
# 0                                          SEE BELOW
# 1  linux/unix, network monitoring, incident respo...
# 2  Enterprise Solutions Architecture, business in...
# 3                         Please see job description
# 4  Configuration Management, Developer, Linux, Ma...
#
#                                 jobdescription_clean  \
# 0  looking for selenium engineers must have solid...
# 1  the university of chicago has a rapidly growin...
# 2  galaxe solutionsevery day our solutions affect...
# 3  java developerfull time direct hirebolingbrook...
# 4  midtown based high tech firm has an immediate ...
#
#                                         skills_clean
# 0                                                NaN
# 1  ['linux', 'unix', 'network monitoring', 'incid...
# 2  ['enterprise solutions architecture', 'busines...
# 3                                                NaN
# 4  ['configuration management', 'developer', 'lin...

# %% [markdown]
# ## 1. TF-IDF Feature Engineering ve K-means Clustering

# %%
vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=5000
)

X = vectorizer.fit_transform(df["jobdescription_clean"])
X.shape
# Out:
# (22000, 5000)

# %%
k = 10
kmeans = MiniBatchKMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(X)

df["cluster"] = clusters
df["cluster"].value_counts()
# Out:
# cluster
# 4    6056
# 7    4037
# 1    3065
# 2    2501
# 5    2327
# 3    1969
# 0     788
# 8     539
# 6     416
# 9     302
# Name: count, dtype: int64

# %%
df.groupby("cluster")["jobtitle"].apply(lambda x: x.value_counts().head(5))
# Out:
# cluster
# 0        Security Engineer                                           34
#          Security Analyst                                            19
#          Security Architect                                          11
#          Senior Security Engineer                                    11
#          Information Security Analyst                                 9
# 1        Java Developer                                             100
#          .Net Developer                                              52
#          Web Developer                                               37
#          Software Engineer                                           37
#          .NET Developer                                              32
# 2        Network Engineer                                           117
#          Systems Administrator                                       42
#          Systems Engineer                                            40
#          Senior Network Engineer                                     38
#          System Administrator                                        25
# 3        Data Analyst                                                36
#          Data Scientist                                              26
#          Data Architect                                              24
#          Data Engineer                                               13
#          Big Data Architect                                          13
# 4        Business Analyst                                            35
#          Technical Recruiter                                         26
#          Project Manager                                             25
#          Salesforce Developer                                        24
#          Technical Writer                                            18
# 5        DevOps Engineer                                             50
#          Software Engineer                                           39
#          Senior Software Engineer                                    31
#          Software Development Engineer                               27
#          Java Developer                                              25
# 6        Software Engineer                                            6
#          Java Developer                                               4
#          DevOps Engineer                                              4
#          Software Developer II with .Net programming experience!      2
#          CCIE / Sr. Cisco UC Consulting Engineer - Relo offered       2
# 7        Project Manager                                            112
#          Business Analyst                                            71
#          Technical Writer                                            25
#          Business Systems Analyst                                    25
#          Senior Project Manager                                      23
# 8        Oracle HCM Cloud (Fusion) Solution Developer - USDC          3
#          SAP Project Manager                                          3
#          SAP CRM Lead                                                 3
#          SAP FICO Consultant                                          3
#          SAP LSHC Senior Manager (Finance Capability)                 3
# 9        Robert Half Technology Account Executive CS                 39
#          Robert Half Technology Account Executive TS                 33
#          Robert Half Technology Senior Recruiter CS                  24
#          Robert Half Technology Technology Recruiter TS              16
#          Robert Half Technology Technology Recruiter CS              15
# Name: jobtitle, dtype: int64

# %% [markdown]
# ## 2. Skill Listelerini Parse Etme ve Temizleme

# %%
# skills_clean string -> list dönüşümü
df_skills = df.dropna(subset=["skills_clean"]).copy()
df_skills["skills_clean"] = df_skills["skills_clean"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)
df_skills["skills_clean"].head()
# Out:
# 1    [linux, unix, network monitoring, incident res...
# 2    [enterprise solutions architecture, business i...
# 4    [configuration management, developer, linux, m...
# 5               [fico, ar, ap, asset management, haha]
# 6    [cisco, dns, http, networking, network enginee...
# Name: skills_clean, dtype: object

# %%
def clean_skill(skill):
    skill = skill.lower().strip()
    
    remove_list = ["see below", "please see job description", "haha"]
    for bad in remove_list:
        if bad in skill:
            return None
    
    skill = re.sub(r"[^a-z0-9#+. ]", "", skill)
    skill = skill.strip(" .,+-")
    
    if len(skill) == 0:
        return None
    
    return skill

def rebuild_skills_list(skill_list):
    if not isinstance(skill_list, list):
        return None
    
    cleaned = []
    for sk in skill_list:
        sk2 = clean_skill(sk)
        if sk2:
            cleaned.append(sk2)
    
    return cleaned if cleaned else None

df_skills["skills_filtered"] = df_skills["skills_clean"].apply(rebuild_skills_list)
df_skills[["skills_clean", "skills_filtered"]].head(10)
# Out:
#                                          skills_clean  \
# 1   [linux, unix, network monitoring, incident res...
# 2   [enterprise solutions architecture, business i...
# 4   [configuration management, developer, linux, m...
# 5              [fico, ar, ap, asset management, haha]
# 6   [cisco, dns, http, networking, network enginee...
# 7   [.net, c#, mvc, restful web services, http, aw...
# 8   [c++, developer, development, javascript, user...
# 10                                        [openstack]
# 11  [unix, iam, scripting knowledge, oim, windows,...
# 12                                        [java, oss]
#
#                                       skills_filtered
# 1   [linux, unix, network monitoring, incident res...
# 2   [enterprise solutions architecture, business i...
# 4   [configuration management, developer, linux, m...
# 5                    [fico, ar, ap, asset management]
# 6   [cisco, dns, http, networking, network enginee...
# 7   [net, c#, mvc, restful web services, http, aws...
# 8   [c, developer, development, javascript, user i...
# 10                                        [openstack]
# 11  [unix, iam, scripting knowledge, oim, windows,...
# 12                                        [java, oss]

# %% [markdown]
# ## 3. Cluster Bazlı Skill Profilleri

# %%
cluster_skill_profiles = {}

for c in sorted(df_skills["cluster"].unique()):
    skills = []
    for row in df_skills[df_skills["cluster"] == c]["skills_filtered"]:
        if isinstance(row, list):
            skills.extend(row)
    cluster_skill_profiles[c] = Counter(skills).most_common(20)

# %%
for c, skills in cluster_skill_profiles.items():
    print(f"\nCLUSTER {c}")
    for skill, count in skills[:10]:
        print(f"{skill} → {count}")
# Out:
# CLUSTER 0
# security → 227
# cissp → 141
# management → 77
# development → 53
# analysis → 51
# linux → 50
# unix → 39
# siem → 39
# ids → 39
# python → 39
#
# CLUSTER 1
# javascript → 758
# java → 704
# css → 460
# html → 455
# sql → 444
# c# → 437
# jquery → 341
# net → 316
# asp.net → 273
# j2ee → 271
#
# CLUSTER 2
# windows → 332
# cisco → 313
# vmware → 293
# linux → 263
# security → 218
# active directory → 202
# management → 192
# hardware → 174
# networking → 162
# wan → 162
#
# CLUSTER 3
# sql → 502
# hadoop → 178
# etl → 175
# java → 163
# python → 149
# oracle → 139
# development → 127
# business intelligence → 120
# management → 110
# analysis → 103
#
# CLUSTER 4
# sql → 333
# java → 332
# development → 217
# management → 192
# linux → 163
# javascript → 158
# sales → 153
# project → 151
# oracle → 136
# security → 133
#
# CLUSTER 5
# java → 630
# linux → 385
# python → 371
# development → 343
# javascript → 279
# aws → 247
# agile → 211
# management → 210
# c → 205
# programming → 188
#
# CLUSTER 6
# javascript → 179
# sql → 107
# python → 83
# java → 79
# css → 76
# c# → 72
# c → 69
# html → 66
# mysql → 63
# linux → 62
#
# CLUSTER 7
# management → 443
# development → 427
# project → 397
# agile → 385
# sql → 370
# project management → 322
# testing → 301
# java → 299
# analysis → 271
# project manager → 222
#
# CLUSTER 8
# sap → 165
# development → 136
# consulting → 136
# http → 120
# excel → 119
# management → 112
# project → 106
# html → 99
# research → 96
# recruiter → 95
#
# CLUSTER 9
# development → 182
# customer service → 180
# management → 150
# networking → 149
# recruiter → 106
# database → 54
# materials → 48
# video → 41
# http → 40
# sun → 37
